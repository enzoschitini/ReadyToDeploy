# %% [markdown]
# # 🚀 Projeto Prático — Módulo 02: A primeira semana cheia da Cantina da Vó
#
# ---
#
# No Módulo 02 você descobriu que dá para guardar muita informação em uma única variável, usando **listas**, **conjuntos** e **dicionários**. Agora é hora de usar essas estruturas de verdade: neste projeto você volta à Sabor Express para organizar os pedidos, os bairros, o cardápio e a equipe de entregadores da Cantina da Vó, sem precisar criar uma variável para cada dado.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# Depois do seu primeiro dia, a integração da **Cantina da Vó** foi um sucesso: o painel que você montou para a Ana Lívia rodou a diretoria inteira, e o Diego ainda está se gabando daquele ticket médio de R\$ 64,03. 😄
#
# Só que agora a Cantina da Vó completou a **primeira semana cheia** dentro do app, e o volume de dados cresceu. São dezenas de pedidos, vários bairros, um cardápio que muda toda hora e entregadores novos chegando. Guardar tudo isso em variáveis soltas, como no primeiro dia, virou impossível.
#
# O time te chamou de novo no chat com as tarefas de hoje. Cada missão pede uma estrutura de dados diferente e, no final, você vai juntar tudo em um resumo da semana para a reunião de sexta.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu. Teste, erre, corrija e tente de novo: é assim que se aprende a programar.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Criação e alteração de **listas** (índices, fatiamento, `.append()`, `.remove()`, `.pop()`, `.insert()`) e a soma de seus itens com `sum()`;
# - Uso de **conjuntos** para eliminar repetições e comparar coleções (`set()`, diferença `-`, `.add()`);
# - Organização de dados no formato chave-valor com **dicionários** (acesso, atualização, `.update()`, `.pop()`, `.get()`, `.keys()` e `.values()`);
# - Combinação de estruturas: **listas de dicionários** e **dicionários compostos**.
#
# Tudo aqui acontece dentro da mesma história, do jeito que aconteceria em um projeto de verdade.

# %% [markdown]
# ## 🧰 Requisitos
#
# Antes de começar, confira se você tem em mãos:
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos do Módulo 01 | Variáveis, números, *strings*, *f-strings* e booleanos |
# | 📘 Conceitos do Módulo 02 | Listas, conjuntos e dicionários |
# | 🧠 Funções nativas | `print()`, `len()`, `round()`, `sum()`, `list()`, `set()`, `dict()` |
# | 🔧 Métodos | Listas: `.append()`, `.insert()`, `.remove()`, `.pop()`; conjuntos: `.add()`; dicionários: `.update()`, `.pop()`, `.get()`, `.keys()`, `.values()` |
# | 📦 Bibliotecas externas | Nenhuma! Só Python puro |
#
# Não é necessário nenhum conhecimento além do que foi visto nos Módulos 01 e 02. Se alguma missão parecer difícil, a dica de cada uma aponta a seção certa para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**, na ordem em que o time te chamou:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Extrato de pedidos da sexta | Listas |
# | 2️⃣ | Mapa de bairros atendidos | Conjuntos |
# | 3️⃣ | Cardápio atualizado | Dicionários |
# | 4️⃣ | Cadastro dos entregadores | Listas de dicionários e dicionários compostos |
# | 5️⃣ | Resumo da semana | Tudo junto! |
#
# Em cada missão você vai encontrar:
#
# - 💬 uma mensagem de alguém do time, com o pedido;
# - 💻 uma célula de código com os dados já prontos e comentários `# TODO` indicando onde você precisa escrever;
# - 🔎 **Resultado esperado**, uma prévia do que deve aparecer na tela quando estiver certo;
# - 💡 **Dica**, para quando bater aquele branco.
#
# Bora lá?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Extrato de pedidos da sexta
#
# > 💬 **Diego (Financeiro):** "Bom dia! Exportei os pedidos de sexta da Cantina da Vó, mas o extrato veio com problema: um valor foi digitado errado, um pedido foi cancelado e dois pedidos atrasados nem entraram. Arruma a lista pra mim e me passa o total, o ticket médio e quanto o jantar rendeu? 🤑"
#
# Os pedidos de sexta estão na lista `pedidos_sexta`, na ordem em que chegaram.
#
# **Sua missão:**
#
# 1. O pedido da **posição 2** foi digitado como `4.59`, mas o valor certo é `45.90`: corrija-o **pela posição**;
# 2. O pedido de `27.00` foi **cancelado**: remova-o **pelo valor**;
# 3. Adicione ao **final** da lista os dois pedidos atrasados: `58.40` e `33.10`, nessa ordem;
# 4. Calcule `total_vendas_sexta`, `quantidade_pedidos_sexta` e `ticket_medio_sexta` (arredondado para 2 casas decimais);
# 5. Os **três últimos** pedidos da lista (já corrigida) foram do jantar: guarde-os em `pedidos_jantar` e calcule o `total_jantar`;
# 6. Imprima tudo com rótulos, como no resultado esperado.

# %%
# 🧾 Pedidos de sexta da Cantina da Vó, na ordem em que chegaram (R$)
pedidos_sexta = [48.90, 32.50, 4.59, 61.20, 27.00, 39.90]

# TODO 1: corrija o pedido da posição 2 para 45.90


# TODO 2: remova o pedido cancelado de 27.00


# TODO 3: adicione os pedidos atrasados 58.40 e 33.10 ao final


# TODO 4: total_vendas_sexta, quantidade_pedidos_sexta e ticket_medio_sexta


# TODO 5: pedidos_jantar (os três últimos) e total_jantar
# (lembre que índices negativos contam a partir do final)


# TODO 6: imprima os resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Pedidos corrigidos: [48.9, 32.5, 45.9, 61.2, 39.9, 58.4, 33.1]
# Total de vendas:    R$ 319.90
# Quantidade:         7 pedidos
# Ticket médio:       R$ 45.70
# Pedidos do jantar:  [39.9, 58.4, 33.1]
# Total do jantar:    R$ 131.40
# ```

# %% [markdown]
# > 💡 **Dica:** repare que a correção vem **antes** da remoção: se você remover primeiro, os itens mudam de posição. A seção 1.3 do Módulo 02 mostra como alterar um item pelo índice e como fatiar uma lista; a seção 1.4 traz `.remove()` e `.append()`; e o `sum()` aparece na seção 1.6, no extrato bancário. Para pegar os três últimos, combine índice negativo com fatiamento sem o fim, como em `email[12:]` (Módulo 01, seção 4.3).

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Mapa de bairros atendidos
#
# > 💬 **Paula (Integração de Dados):** "Recebi a lista de bairros de todos os pedidos da semana da Cantina da Vó, com repetição e tudo. Preciso saber quantos bairros diferentes eles atendem e se algum deles ainda está fora da área de entrega da Sabor Express. O Rafa já aprovou: se tiver bairro de fora, pode incluir na nossa área."
#
# **Sua missão:**
#
# 1. Conte quantos pedidos a semana teve e guarde em `bairros_atendidos_cantina` os bairros **sem repetição**;
# 2. Crie `bairros_fora_da_area` com os bairros que a Cantina da Vó atende, mas que **não** estão em `area_sabor_express`;
# 3. Inclua esse bairro em `area_sabor_express` (ele está em `bairros_fora_da_area`, mas escreva o nome dele diretamente no código);
# 4. Recalcule os bairros que ainda ficaram de fora e imprima tudo com rótulos, como no resultado esperado.

# %%
# 🗺️ Bairro de cada pedido da Cantina da Vó na semana
bairros_pedidos_semana = [
    'Pinheiros', 'Vila Mariana', 'Pinheiros', 'Moema', 'Centro', 'Vila Mariana',
    'Pinheiros', 'Centro', 'Bela Vista', 'Moema', 'Centro', 'Bela Vista',
]

# 🚚 Bairros onde a Sabor Express já faz entregas
area_sabor_express = {'Pinheiros', 'Vila Mariana', 'Centro', 'Bela Vista', 'Liberdade', 'Consolação'}

# TODO 1: bairros_atendidos_cantina (sem repetição)


# TODO 2: bairros_fora_da_area


# TODO 3: inclua o bairro que ficou de fora em area_sabor_express


# TODO 4: recalcule os bairros fora da área e imprima os resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Pedidos na semana:          12
# Bairros diferentes:         5
# Bairros fora da área:       {'Moema'}
# Bairros na área atualizada: 7
# Bairros fora da área agora: set()
# ```

# %% [markdown]
# > 💡 **Dica:** converter a lista para conjunto é o mesmo truque das hashtags da seção 2.6 do Módulo 02, e a diferença entre conjuntos com `-` está na seção 2.3 (lembre que a ordem dos operandos importa!). O `set()` no final não é erro: é um conjunto **vazio**, igual ao que apareceu no exemplo da Escandinávia.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Cardápio atualizado
#
# > 💬 **Marina (Gerente de Cadastro):** "Oii! O cardápio da Cantina da Vó no app está desatualizado. Tem reajuste de preço, prato novo e prato saindo. E um cliente perguntou pelo chat se tem pizza... acho que não, mas confirma pra mim sem travar o sistema? 🙏"
#
# O cardápio está no dicionário `cardapio_cantina`, no formato `{prato: preço}`.
#
# **Sua missão:**
#
# 1. Guarde em `preco_lasanha` o preço da lasanha;
# 2. Aplique o reajuste com **um único** `.update()`: nhoque passa a custar `38.90` e espaguete, `35.90`;
# 3. Adicione o prato novo `'polenta frita'`, que custa `24.90`;
# 4. O risoto saiu do cardápio (o fornecedor de arroz arbóreo atrasou): remova-o e guarde o preço removido em `preco_risoto_removido`;
# 5. Busque o preço de `'pizza'` **sem gerar erro** e guarde em `preco_pizza`;
# 6. Crie `pratos_cardapio` e `precos_cardapio`, listas com os nomes e os preços do cardápio atualizado, e calcule `preco_medio_cardapio` (2 casas decimais);
# 7. Imprima tudo com rótulos, como no resultado esperado.

# %%
# 🍝 Cardápio da Cantina da Vó no app: {prato: preço em R$}
cardapio_cantina = {
    'lasanha': 42.90,
    'nhoque': 36.50,
    'espaguete': 34.90,
    'risoto': 48.00,
    'tiramisu': 22.00,
}

# TODO 1: preco_lasanha


# TODO 2: reajuste do nhoque e do espaguete com um único .update()


# TODO 3: adicione a 'polenta frita'


# TODO 4: remova o risoto e guarde o preço em preco_risoto_removido


# TODO 5: preco_pizza, sem gerar KeyError


# TODO 6: pratos_cardapio, precos_cardapio e preco_medio_cardapio


# TODO 7: imprima os resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Preço da lasanha:      R$ 42.90
# Risoto removido:       R$ 48.00
# Preço da pizza:        None
# Pratos no cardápio:    ['lasanha', 'nhoque', 'espaguete', 'tiramisu', 'polenta frita']
# Preços no cardápio:    [42.9, 38.9, 35.9, 22.0, 24.9]
# Preço médio do prato:  R$ 32.92
# ```

# %% [markdown]
# > 💡 **Dica:** o acesso e a inclusão de um prato novo usam colchetes com a chave (seção 3.3 do Módulo 02). Para buscar a pizza sem gerar `KeyError`, use `.get()`; o `.update()` e o `.pop()` estão na seção 3.4, e a conversão com `.keys()` e `.values()`, na seção 3.5. Repare que, sem o risoto, a polenta entra no **final** do cardápio.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Cadastro dos entregadores
#
# > 💬 **Rafa (Operações):** "Urgente de novo! 😅 O João finalmente pediu pra trocar a senha pra `vo2024`, aquela que ele vivia digitando. E o Bruno começa hoje como entregador e ainda não está no sistema. Resolve as duas coisas e me confirma os dados da equipe, por favor?"
#
# Os entregadores estão na lista `equipe_entregadores`. Cada entregador é um **dicionário**, e o veículo de cada um é **outro dicionário** dentro dele.
#
# **Sua missão:**
#
# 1. Troque a senha do João (o primeiro da lista) para `'vo2024'`;
# 2. Crie o dicionário `entregador_novo` para o Bruno, **com as mesmas chaves** dos outros entregadores: nome `'Bruno'`, usuário `'bruno.rota'`, senha `'rota77'` e veículo do tipo `'moto'` com placa `'SPX4F21'`. Depois, adicione-o ao final da equipe;
# 3. Crie `total_entregadores`, `veiculo_carla` (o tipo de veículo da Carla) e `placa_bruno` (a placa do último entregador da lista);
# 4. Crie `acesso_joao_liberado`, comparando a senha que o João digitou hoje (`senha_digitada_joao`) com a senha que está no cadastro dele;
# 5. Imprima tudo com rótulos, como no resultado esperado.

# %%
# 🛵 Equipe de entregadores da Cantina da Vó
equipe_entregadores = [
    {
        'nome': 'João',
        'usuario': 'joao.entregador',
        'senha': 'vo2023',
        'veiculo': {'tipo': 'moto', 'placa': 'BRA2E19'},
    },
    {
        'nome': 'Carla',
        'usuario': 'carla.entregas',
        'senha': 'c4rl4',
        'veiculo': {'tipo': 'bicicleta', 'placa': None},
    },
]

# Senha que o João digitou hoje na tela de login
senha_digitada_joao = 'vo2024'

# TODO 1: troque a senha do João para 'vo2024'


# TODO 2: crie entregador_novo (Bruno) e adicione-o à equipe


# TODO 3: total_entregadores, veiculo_carla e placa_bruno


# TODO 4: acesso_joao_liberado


# TODO 5: imprima os resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Total de entregadores: 3
# Veículo da Carla:      bicicleta
# Placa do Bruno:        SPX4F21
# Acesso do João liberado? True
# ```

# %% [markdown]
# > 💡 **Dica:** para chegar em um valor lá dentro, encadeie os colchetes do nível mais externo para o mais interno: primeiro a posição na lista, depois a chave do entregador, depois a chave do veículo, como em `cadastro['andre']['mae']['ano_nascimento']` (seção 3.2 do Módulo 02). A ideia de guardar dicionários dentro de uma lista é a mesma das redes wi-fi da seção 3.6. No primeiro dia, o acesso do João foi negado; se agora ainda deu `False`, confira se a senha foi mesmo trocada no cadastro.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Resumo da semana
#
# > 💬 **Ana Lívia (CEO):** "Que semana! Quero levar os números da Cantina da Vó pra reunião de amanhã de manhã, mas dessa vez organizados de um jeito que o sistema consiga reaproveitar depois. Monta um resumo com os indicadores principais e me mostra bonitinho na tela?"
#
# **Sua missão:**
#
# 1. Crie o dicionário `resumo_semana`, com uma chave para cada indicador abaixo e o valor vindo das variáveis das missões anteriores:
#    - total de vendas e ticket médio de sexta (Missão 1);
#    - quantidade de bairros na área de entrega atualizada (Missão 2);
#    - quantidade de pratos e preço médio do cardápio (Missão 3);
#    - quantidade de entregadores (Missão 4);
# 2. Imprima a lista de indicadores do resumo (as **chaves** do dicionário);
# 3. Monte um painel com `print()` e *f-strings*, lendo os valores **de dentro do** `resumo_semana`.
#
# Aqui **não existe gabarito único**: os nomes das chaves e o visual do painel são escolha sua.

# %%
# 📊 Resumo da semana da Cantina da Vó na Sabor Express
# TODO 1: crie o dicionário resumo_semana reaproveitando as variáveis das Missões 1 a 4


# TODO 2: imprima a lista de indicadores (chaves) do resumo


# TODO 3: monte o painel lendo os valores de dentro de resumo_semana

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode, e deve, ficar diferente; essa é só uma ideia de formato):
#
# ```
# Indicadores: ['total_vendas_sexta', 'ticket_medio_sexta', 'bairros_atendidos', 'pratos_no_cardapio', 'preco_medio_cardapio', 'entregadores']
# ==========================================
# 🍝 Cantina da Vó — Resumo da semana
# ==========================================
# Vendas de sexta:       R$ 319.90
# Ticket médio de sexta: R$ 45.70
# Bairros atendidos:     7
# Pratos no cardápio:    5
# Preço médio do prato:  R$ 32.92
# Entregadores:          3
# ==========================================
# ```

# %% [markdown]
# > 💡 **Dica:** dentro de uma *f-string* feita com aspas simples, use aspas **duplas** na chave do dicionário (ou o contrário): `f"Vendas: {resumo_semana['total_vendas_sexta']}"`. Assim o Python não confunde onde o texto termina. Para as quantidades, lembre que `len()` funciona com conjuntos e dicionários também.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 02. Os desafios abaixo são **totalmente opcionais**: encare como um "modo difícil" para quem quer espremer um pouco mais as estruturas de dados. Vá na ordem que quiser, ou pule direto para o que mais te chamar atenção.

# %% [markdown]
# ### 🥞 Extra 1 — Fila da cozinha
#
# A cozinha recebe os pratos em uma lista, na ordem dos pedidos. O cliente do **último** pedido cancelou: remova-o com `.pop()` **sem argumento** e guarde o prato em `prato_cancelado`. Em seguida, um pedido VIP de `'polenta frita'` precisa furar a fila e entrar na **primeira** posição. Imprima o prato cancelado e a fila atualizada.

# %%
# 🥞 Extra 1: fila da cozinha
fila_cozinha = ['lasanha', 'nhoque', 'espaguete', 'tiramisu']

# TODO: crie prato_cancelado, coloque o pedido VIP no início e imprima os dois

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Prato cancelado:  tiramisu
# Fila da cozinha:  ['polenta frita', 'lasanha', 'nhoque', 'espaguete']
# ```

# %% [markdown]
# ### 🤝 Extra 2 — Clientes em comum
#
# A Paula quer saber quais clientes já compravam nas **duas** empresas antes da integração, e quantos clientes **únicos** a Sabor Express tem agora somando as duas bases. Use os operadores `&` (interseção) e `|` (união), mencionados na seção 2.3 do Módulo 02, para criar `clientes_em_comum` e `clientes_unicos`.

# %%
# 🤝 Extra 2: clientes em comum
clientes_cantina = {'ana.paula', 'marcos.lima', 'bia.rocha'}
clientes_sabor_express = {'ana.paula', 'leo.souza', 'caio.m', 'rita.alves'}

# TODO: crie clientes_em_comum e clientes_unicos e imprima o primeiro e a quantidade do segundo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Clientes nas duas bases:   {'ana.paula'}
# Total de clientes únicos:  6
# ```

# %% [markdown]
# ### 🔐 Extra 3 — Senha forte?
#
# O Rafa quer uma regra nova: a senha só é **forte** se tiver pelo menos **6 caracteres diferentes**. A nova senha do João, `'vo2024'`, tem 6 caracteres... ela passa? Pense antes de testar 😉. Converta a senha em um conjunto para descobrir `caracteres_diferentes` e crie `senha_forte` com uma comparação.

# %%
# 🔐 Extra 3: a nova senha do João é forte?
senha_nova_joao = 'vo2024'

# TODO: crie caracteres_diferentes e senha_forte e imprima com rótulos
# (imprima também o total de caracteres, com len(), para comparar)

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Caracteres na senha:    6
# Caracteres diferentes:  5
# Senha forte?            False
# ```

# %% [markdown]
# ### 🔑 Extra 4 — O cardápio do sistema antigo
#
# A Marina encontrou o cardápio no sistema antigo da Cantina da Vó e reparou que a lasanha aparece **duas vezes**, com preços diferentes. Antes de rodar: quantos pratos você acha que esse dicionário tem, e qual preço da lasanha vai valer? Depois, imprima a quantidade de pratos e o preço da lasanha para conferir o seu palpite.

# %%
# 🔑 Extra 4: cardápio do sistema antigo, com uma chave repetida
cardapio_sistema_antigo = {
    'lasanha': 39.90,
    'nhoque': 33.00,
    'lasanha': 44.50,
}

# TODO: imprima a quantidade de pratos e o preço da lasanha com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Pratos no cardápio antigo: 2
# Preço da lasanha:          R$ 44.50
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Cardápio estiloso
#
# Use o `cardapio_cantina` da Missão 3 para montar um cardápio decorado, pronto para ir para a vitrine do app: título em maiúsculas, linhas separadoras e o preço de cada prato. Combine acesso por chave, *f-strings*, `.title()` e a repetição de caracteres com `*`. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: seu cardápio estiloso
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# Sem provas, sem notas: só uma conferida rápida para você saber onde está.
#
# - [ ] Alterei uma lista pelo índice e usei `.remove()` e `.append()` para corrigir os dados
# - [ ] Fatiei uma lista com índice negativo e somei os itens com `sum()`
# - [ ] Eliminei repetições convertendo uma lista em conjunto com `set()`
# - [ ] Comparei dois conjuntos com o operador `-` e incluí um item com `.add()`
# - [ ] Acessei, atualizei, adicionei e removi itens de um dicionário (`.update()`, `.pop()`)
# - [ ] Busquei uma chave inexistente com `.get()` sem travar o programa
# - [ ] Converti as chaves e os valores de um dicionário em listas com `.keys()` e `.values()`
# - [ ] Naveguei em uma lista de dicionários compostos encadeando colchetes
# - [ ] Montei um dicionário de resumo reaproveitando os resultados das outras missões
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: a Cantina da Vó fechou a primeira semana cheia com os dados em ordem, graças a você. 🎉
#
# Mas repare em uma coisa: hoje você corrigiu, removeu e buscou cada item **um de cada vez**, sabendo exatamente onde ele estava. E se a lista tivesse 500 pedidos e você precisasse analisar todos, ou decidir algo diferente para cada um? No **Módulo 03** a história continua com **fluxo condicional e repetição**: você vai aprender a tomar decisões com `if`, tratar erros com `try` e percorrer listas e dicionários inteiros com `for`.
